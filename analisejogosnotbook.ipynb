# %%
import pandas as pandinha 
import numpy as np
import os


import matplotlib
import matplotlib.pyplot as plotGrafico
import seaborn as sns


# !pip install dataprep
from dataprep.eda import *
from dataprep.datasets import load_dataset
from dataprep.eda import create_report
from dataprep.eda import plot
from dataprep.eda import plot_correlation
from dataprep.eda.missing import plot_missing

import warnings
warnings.filterwarnings("ignore")



fontdados = pandinha.read_csv('data/vgsales.csv',index_col='Rank')



fontdados



fontdados.columns




fontdados.info()





fig, axarr = plotGrafico.subplots(1, 2, figsize=(20, 8))

fontdados.dtypes.value_counts().plot.pie(explode=[0.1,0.1],autopct='%1.1f%%',shadow=True,ax=axarr[1])
plotGrafico.title('Tipo de dados')

fontdados.dtypes.value_counts().plot(kind='bar',ax=axarr[0])
plotGrafico.title('Tipo de dados');





fig, axarr = plotGrafico.subplots(1, 2, figsize=(20, 8))

fontdados.Platform.value_counts().plot.pie(shadow=True,ax=axarr[1])


fontdados.Platform.value_counts().plot(kind='bar',ax=axarr[0])
plotGrafico.title('Todas as plataformas de jogos');





matplotlib.rcParams['figure.figsize'] =[15,10]
fontdados.Name.value_counts().head(100).plot(kind='bar')
plotGrafico.title('top 100 franquias mais vendidas')




fig, axarr = plotGrafico.subplots(1, 2, figsize=(20, 8))

fontdados.Genre.value_counts().plot.pie(shadow=True,ax=axarr[1])


fontdados.Genre.value_counts().plot(kind='bar',ax=axarr[0])
plotGrafico.title('Todos os Jogos Por Genero');
